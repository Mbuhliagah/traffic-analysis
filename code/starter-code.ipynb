# %% [markdown]
# # Project 1: Driving Licenses, Traffic Accidents and Casualties Analysis

# %% [markdown]
# ## Problem Statment
#
# Craft your problem statement here using the prompt from the README and other sources you find during your investigation.

# %% [markdown]
# Accidents and causality is one of the biggest concern in most countries. There are many research and studies to find a solutions for this misfortune. Saudi Arabia reports and data shows that it one of the highest in accidents. We will try to analysis this datasets and understand the reason behind such an events. The datasets is sample of the traffic accidents and Number of driving licenses issued in Saudi Arabia per year and region.Investigating both datasets show the hieghest region with accidents and causality either dead or injured. The indicator of accidents is limited to the time rage of 2016 and 2017. Also, invistigate wich city had the hieghest driving licenses issued for the past two  decade.

# %% [markdown]
# ## Executive Summary
# Write an executive summary that summarizes the problem and your key findings.

# %% [markdown]
# ### Contents:
# - [Datasets Description](#Datasets-Description)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here, including any Jupyter magic commands*

# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %% [markdown]
# ## Datasets Description
#
# [Driving Licenses](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-driving-licenses-issued-in-the-kingdom-2004-2008/information/?disjunctive.administritive_area&sort=time_period&location=5,24.37495,45.08024&basemap=jawg.streets)
# This dataset contains Saudi Arabia Driving Licenses Issued By Administrative Area for 1993 - 2016. Data from General Authority for Statistics . Follow datasource.kapsarc.org for timely data to advance energy economics research.
#
# [Traffic Accidents and Casualties](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-traffic-accidents-and-casualties-injured-dead-2008/export/?disjunctive.region&disjunctive.indicator&sort=time_period)
# This dataset contains Saudi Arabia Traffic Accidents and Casualties by Region for 2016. Data from General Authority for Statistics. Follow datasource.kapsarc.org for timely data to advance energy economics research.

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# #### 1. Read In Driving Licenses & Traffic Accidents Data
# Read in the `saudi-arabia-traffic-accidents-2008.csv` and `saudi-arabia-driving-licenses-2004-2008.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code
traffic = pd.read_csv('../data/saudi-arabia-traffic-accidents-2008.csv', sep=';')
licenses = pd.read_csv('../data/saudi-arabia-driving-licenses-2004-2008.csv', sep=';')

# %% [markdown]
# #### 2. Display data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code
traffic.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year            Region  \
# 0           0             0  (2016)            Makkah
# 1           1             1  (2016)    Eastern Region
# 2           2             2  (2016)            Tabouk
# 3           3             3  (2016)              Hail
# 4           4             4  (2016)              Hail
# 5           5             5  (2016)  Northern Boarder
# 6           6             6  (2017)             Jazan
# 7           7             7  (2017)           Al-Jouf
# 8           8             8  (2017)             Total
# 9           9             9  (2016)  Northern Boarder
#
#                      Indicator   Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383n   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113n  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434n    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299n   27.400845724, 41.4406960508
# ...

# %%
licenses.head(10)
# Out:
#    Unnamed: 0    Year Administritive Area Driving Liceses  \
# 0           0  (2012)              Makkah         143954n
# 1           1  (1994)              Makkah          75349n
# 2           2  (1998)              Makkah          86082n
# 3           3  (2004)              Makkah          86636n
# 4           4  (2005)              Makkah          65099n
# 5           5  (2008)              Makkah          77013n
# 6           6  (2014)             Madinah          31447n
# 7           7  (2013)             Madinah          28513n
# 8           8  (2012)             Madinah          14459n
# 9           9  (1994)             Madinah           3767n
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334
# 1  21.628962766, 41.2636898334
# 2  21.628962766, 41.2636898334
# 3  21.628962766, 41.2636898334
# 4  21.628962766, 41.2636898334
# 5  21.628962766, 41.2636898334
# 6  24.927534539, 39.4918237173
# 7  24.927534539, 39.4918237173
# 8  24.927534539, 39.4918237173
# ...

# %% [markdown]
# #### 3. Briefly describe the data
#
# Take your time looking through the data and briefly describe the data in the markdown cell below. Note things about what the columns might mean, and the general information that is conveyed in the dataframe.

# %% [markdown]
# Answer:

# %% [markdown]
# <font color='Blue'>
# The first data set Traffic:
#     contain the number of accident and casualties either injured or dead by each city and what year.
#     </n>
# The second data set License:
#     contain the number of licenses issued by each city in timestapm "year"
# </font>

# %% [markdown]
# #### 4a. How complete is the data?
#
# Investigate missing values etc.

# %%
#Code
traffic.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Year            0
# Region          0
# Indicator       0
# Value           0
# geo_point_2d    6
# dtype: int64

# %%
licenses.isnull().sum()
# Out:
# Unnamed: 0              0
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# dtype: int64

# %%
#
#there are 6 geo_point in traffic and 25 geo_point in licenses are null 
# geo_point_2d null value has no important to the dataframe as itmis set to the total 
#

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each dataset? What is the maximum *possible* value?**

# %%
traffic_w_total=traffic[traffic.Region != 'Total']

# %%
licenses_w_total=licenses[licenses['Administritive Area'] != 'Total']

# %%
print ('The possible max value for Traffic dataset is {} and the minimum is {}'.format(traffic_w_total.Value.max(),traffic.Value.min()))
print ('The possible max value for Licenses dataset is {} and the minimum is {}'.format(licenses_w_total['Driving Liceses'].max(),licenses['Driving Liceses'].min()))
# Out:
# The possible max value for Traffic dataset is 99925n and the minimum is 1007n
# The possible max value for Licenses dataset is 9983n and the minimum is 100291n

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
traffic.dtypes
# Out:
# Unnamed: 0       int64
# Unnamed: 0.1     int64
# Year            object
# Region          object
# Indicator       object
# Value           object
# geo_point_2d    object
# dtype: object

# %%
licenses.dtypes
# Out:
# Unnamed: 0              int64
# Year                   object
# Administritive Area    object
# Driving Liceses        object
# geo_point_2d           object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:

# %% [markdown]
# <font color='blue'>
# year columns in both data set shoud be changed to timestamp
# unnamed columns in both dataset is the same as the index so it should be removed
# number of indicator and driving licenses removed the n in the end of each value and change the type from string to float
#     </font>

# %% [markdown]
# #### 6. Fix incorrect data types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert numerical columns to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
traffic.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year          Region  \
# 0           0             0  (2016)          Makkah
# 1           1             1  (2016)  Eastern Region
# 2           2             2  (2016)          Tabouk
# 3           3             3  (2016)            Hail
# 4           4             4  (2016)            Hail
#
#                      Indicator   Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383n   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113n  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434n    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299n   27.400845724, 41.4406960508
# 4             No. of Accidents  10199n   27.400845724, 41.4406960508

# %%
licenses.head()
# Out:
#    Unnamed: 0    Year Administritive Area Driving Liceses  \
# 0           0  (2012)              Makkah         143954n
# 1           1  (1994)              Makkah          75349n
# 2           2  (1998)              Makkah          86082n
# 3           3  (2004)              Makkah          86636n
# 4           4  (2005)              Makkah          65099n
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334
# 1  21.628962766, 41.2636898334
# 2  21.628962766, 41.2636898334
# 3  21.628962766, 41.2636898334
# 4  21.628962766, 41.2636898334

# %%
#code
# removing the n letter from the value in both datasets and change the type to float
traffic['Value'] = traffic['Value'].apply(lambda x: float(x[:-1]))

# %%
licenses['Driving Liceses'] = licenses['Driving Liceses'].apply(lambda x: float(x[:-1]))

# %%
licenses.head(2)
# Out:
#    Unnamed: 0    Year Administritive Area  Driving Liceses  \
# 0           0  (2012)              Makkah         143954.0
# 1           1  (1994)              Makkah          75349.0
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334
# 1  21.628962766, 41.2636898334

# %%
traffic.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year          Region  \
# 0           0             0  (2016)          Makkah
# 1           1             1  (2016)  Eastern Region
#
#                      Indicator    Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383.0   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113.0  23.2883307307, 50.1478302439

# %% [markdown]
# - Make new columns `x` and `y` using `geo_point_2d`

# %%
#splite the geo_point_2d to two columns x and y

# %%
traffic[['x','y']] = traffic.geo_point_2d.str.split(",", expand=True)

# %%
licenses[['x','y']] = licenses.geo_point_2d.str.split(",", expand=True)

# %%
traffic.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year          Region  \
# 0           0             0  (2016)          Makkah
# 1           1             1  (2016)  Eastern Region
# 2           2             2  (2016)          Tabouk
# 3           3             3  (2016)            Hail
# 4           4             4  (2016)            Hail
#
#                      Indicator    Value                  geo_point_2d  \
# 0  No. of Casualties - Injured  12383.0   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113.0  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434.0    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299.0   27.400845724, 41.4406960508
# 4             No. of Accidents  10199.0   27.400845724, 41.4406960508
#
#                x               y
# 0   21.628962766   41.2636898334
# 1  23.2883307307   50.1478302439
# 2    27.90165499   37.2598581394
# 3   27.400845724   41.4406960508
# 4   27.400845724   41.4406960508

# %%
# delete unused columns from the datasets
traffic = traffic.drop(['Unnamed: 0', 'Unnamed: 0.1', 'geo_point_2d' ], axis=1)

# %%
licenses = licenses.drop(['Unnamed: 0', 'geo_point_2d'], axis=1)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#removing the parentheses from. the value year and change the type to int
traffic['Year'] = traffic.Year.str.replace('[()]', '')

# %%
licenses['Year'] = licenses.Year.str.replace('[()]', '')

# %%
traffic.Year = traffic['Year'].astype(int)

# %%
licenses.Year = licenses['Year'].astype(int)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#fixing names in columns

# %%
traffic.columns = ['year', 'region', 'indicator', 'value', 'x', 'y']

# %%
licenses.columns = ['year', 'administrative_area', 'driving_licenses', 'x', 'y']

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
traffic.dtypes
# Out:
# year           int64
# region        object
# indicator     object
# value        float64
# x             object
# y             object
# dtype: object

# %%
licenses.dtypes
# Out:
# year                     int64
# administrative_area     object
# driving_licenses       float64
# x                       object
# y                       object
# dtype: object

# %% [markdown]
# #### 7. Rename columns
# Change the names of the columns to more expressive names so that you can tell the difference the Driving Licenses  columns and the & Traffic Accidents columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these two datasets, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).
# - Please also fix any typos you see in the column names.

# %%
#code
#fixing names 
traffic.columns = ['year', 'region', 'indicator', 'value', 'x', 'y']
licenses.columns = ['year', 'region', 'driving_licenses', 'x', 'y']

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |Year|int|Traffic_Accidents|Representing the year for the event in the same observation |
# |Region|object|Traffic_Accidents|Region of Saudi Arabia|
# |Indicator|object|Traffic_Accidents|Indicator Categorical columns for the type of casualties and accidents|
# |Value|float|Traffic_Accidents|represent the value of the indicators masured in number |
# |x|object|Traffic_Accidents|geo point Lit|
# |y|float|Traffic_Accidents|geo point Lng|
# |Year|int|Driving_Licenses|Representing the year for the event in the same observation|
# |Region|object|Driving_Licenses|region of saudi where licenses been issued|
# |Driving Liceses|float|Driving_Licenses|number of licenses issued|
# |x|object|Traffic_Accidents|geo point Lit|
# |y|float|Traffic_Accidents|geo point Lng|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# This study concerns accident and license in regions/area. Please do the followings:
# 0. Which rows are not associated with regions?
# 1. Confirm the numbers of all regions add up to total.
# 2. Remove the rows that are not associated with regions

# %%
# Total is not associated with region

# %%
#comparing the values for region with the total
total_2016 = traffic[(traffic['year']==2016) & (traffic['region'] == 'Total')].groupby(by='indicator').sum()[['value']]
total_2017 = traffic[(traffic['year']==2017) & (traffic['region'] == 'Total')].groupby(by='indicator').sum()[['value']]
regions_2016 = traffic[(traffic['year']==2016) & (traffic['region'] != 'Total')].groupby(by='indicator').sum()[['value']]
regions_2017 = traffic[(traffic['year']==2017) & (traffic['region'] != 'Total')].groupby(by='indicator').sum()[['value']]

# %%
total_2016 == regions_2016
# Out:
#                              value
# indicator
# No. of Accidents              True
# No. of Casualties - Dead      True
# No. of Casualties - Injured   True

# %%
total_2017 == regions_2017
# Out:
#                              value
# indicator
# No. of Accidents              True
# No. of Casualties - Dead      True
# No. of Casualties - Injured   True

# %%
# Chacking the values per year with the total for the same year. used max as Total as its the highest value in each year
licenses.groupby('year')['driving_licenses'].sum() - licenses.groupby('year')['driving_licenses'].max() == licenses.groupby('year')['driving_licenses'].max()
# Out:
# year
# 1993    True
# 1994    True
# 1995    True
# 1996    True
# 1997    True
# 1998    True
# 1999    True
# 2000    True
# 2001    True
# 2002    True
# 2003    True
# 2004    True
# 2005    True
# 2006    True
# 2007    True
# 2008    True
# 2009    True
# 2010    True
# 2011    True
# 2012    True
# 2013    True
# 2014    True
# 2015    True
# 2016    True
# 2017    True
# Name: driving_licenses, dtype: bool

# %%
# droping rows containing total
traffic.drop(traffic[traffic.region == 'Total'].index, inplace=True)

# %%
licenses.drop(licenses[licenses.region == 'Total'].index, inplace=True)

# %% [markdown]
# #### 10a. Data formats
# Is the License data in long or wide format? How about the Accident data? And why?

# %%
#code
#its long format

# %% [markdown]
# #### 10b. Changing formats
# Which format would work best for both dataframes? Transform the datasets to the same format before merging in the next task.

# %%
# using pivot table to convert to wide table 
traffic
# Out:
#     year          region                    indicator    value              x  \
# 0   2016          Makkah  No. of Casualties - Injured  12383.0   21.628962766
# 1   2016  Eastern Region     No. of Casualties - Dead   1113.0  23.2883307307
# 2   2016          Tabouk     No. of Casualties - Dead    434.0    27.90165499
# 3   2016            Hail     No. of Casualties - Dead    299.0   27.400845724
# 4   2016            Hail             No. of Accidents  10199.0   27.400845724
# ..   ...             ...                          ...      ...            ...
# 79  2017            Asir  No. of Casualties - Injured   2368.0  19.1387847401
# 80  2017            Hail  No. of Casualties - Injured    773.0   27.400845724
# 81  2017        Al-Baaha     No. of Casualties - Dead    134.0  20.1484058503
# 82  2017        Al-Baaha             No. of Accidents   1414.0  20.1484058503
# 83  2017        Al-Baaha  No. of Casualties - Injured   1007.0  20.1484058503
#
#                  y
# ...

# %%
#code
traffic_w = pd.pivot_table(traffic, columns=['indicator'], values='value', index=['year', 'region', 'x', 'y'])
traffic_w.head()
# Out:
# indicator                                         No. of Accidents  \
# year region         x             y
# 2016 Al-Baaha       20.1484058503  41.4665484892            3618.0
#      Al-Jouf        29.9677445762  39.5570371172           10212.0
#      Asir           19.1387847401  42.941470036            32684.0
#      Eastern Region 23.2883307307  50.1478302439          101619.0
#      Hail           27.400845724   41.4406960508           10199.0
#
# indicator                                         No. of Casualties - Dead  \
# year region         x             y
# 2016 Al-Baaha       20.1484058503  41.4665484892                     185.0
#      Al-Jouf        29.9677445762  39.5570371172                     245.0
#      Asir           19.1387847401  42.941470036                      983.0
#      Eastern Region 23.2883307307  50.1478302439                    1113.0
#      Hail           27.400845724   41.4406960508                     299.0
#
# ...

# %%
traffic_w =  traffic_w.reset_index()
traffic_w
# Out:
# indicator  year            region              x               y  \
# 0          2016          Al-Baaha  20.1484058503   41.4665484892
# 1          2016           Al-Jouf  29.9677445762   39.5570371172
# 2          2016              Asir  19.1387847401    42.941470036
# 3          2016    Eastern Region  23.2883307307   50.1478302439
# 4          2016              Hail   27.400845724   41.4406960508
# 5          2016             Jazan  17.2072313962   42.6525807422
# 6          2016           Madinah   24.927534539   39.4918237173
# 7          2016            Makkah   21.628962766   41.2636898334
# 8          2016            Najran  18.4511003068   46.8688495726
# 9          2016  Northern Boarder   30.197074783   41.8171186952
# 10         2016            Qassim  26.1967063704   43.3429998455
# 11         2016            Riyadh  23.0814341634   45.5857512766
# 12         2016            Tabouk    27.90165499   37.2598581394
# ...

# %% [markdown]
# #### 11. Merge dataframes
#
# Join the Driving Licenses & Traffic Accidents dataframes using the **region** and **year** in each dataframe as the key. Assign this to a new variable. Which join should you use to preserve the most data?

# %%
#code
#combained both dataset using outer join 
#we can use inner but it will lose most of the data so I believe outer is a good choise 
combined_datasets = pd.merge(traffic_w, licenses, left_on=['region', 'year'], right_on=['region', 'year'], how='outer')
combined_inner = pd.merge(traffic_w, licenses, left_on=['region', 'year'], right_on=['region', 'year'], how='inner')

# %%
combined_datasets
# Out:
#      year          region            x_x             y_x  No. of Accidents  \
# 0    2016        Al-Baaha  20.1484058503   41.4665484892            3618.0
# 1    2016         Al-Jouf  29.9677445762   39.5570371172           10212.0
# 2    2016            Asir  19.1387847401    42.941470036           32684.0
# 3    2016  Eastern Region  23.2883307307   50.1478302439          101619.0
# 4    2016            Hail   27.400845724   41.4406960508           10199.0
# ..    ...             ...            ...             ...               ...
# 328  2000          Tabouk            NaN             NaN               NaN
# 329  2006          Tabouk            NaN             NaN               NaN
# 330  2013            Hail            NaN             NaN               NaN
# 331  1997            Hail            NaN             NaN               NaN
# 332  1999            Hail            NaN             NaN               NaN
#
# ...

# %%
#empty value in the dataset

# %%
combined_datasets.isnull().count()
# Out:
# year                           333
# region                         333
# x_x                            333
# y_x                            333
# No. of Accidents               333
# No. of Casualties - Dead       333
# No. of Casualties - Injured    333
# driving_licenses               333
# x_y                            333
# y_y                            333
# dtype: int64

# %%
combined_datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 332
# Data columns (total 10 columns):
# year                           333 non-null int64
# region                         333 non-null object
# x_x                            26 non-null object
# y_x                            26 non-null object
# No. of Accidents               26 non-null float64
# No. of Casualties - Dead       26 non-null float64
# No. of Casualties - Injured    26 non-null float64
# driving_licenses               325 non-null float64
# x_y                            325 non-null object
# y_y                            325 non-null object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 28.6+ KB

# %% [markdown]
# #### 12. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_datasets.csv`.

# %%
#code
combined_datasets.to_csv('../data/combined_datasets.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
combined_datasets.describe()
# Out:
#               year  No. of Accidents  No. of Casualties - Dead  \
# count   333.000000         26.000000                 26.000000
# mean   2005.276276      38225.692308                635.384615
# std       7.349818      46493.705035                549.783381
# min    1993.000000       1414.000000                112.000000
# 25%    1999.000000      10276.250000                241.250000
# 50%    2005.000000      16050.500000                415.500000
# 75%    2012.000000      30981.250000                929.250000
# max    2017.000000     145541.000000               2243.000000
#
#        No. of Casualties - Injured  driving_licenses
# count                    26.000000        325.000000
# mean                   2743.038462      28915.347692
# std                    2922.641127      47419.058819
# min                     374.000000        915.000000
# 25%                     923.000000       4846.000000
# 50%                    1618.500000      10267.000000
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def StdDev(name,columns):
    l={}
    mean=columns.mean()
    length=len(columns)
    l[name]=(np.sqrt(sum([(number - mean) ** 2 for number in columns]) / (len(columns)-1)))
    print(l)

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'Driving_Licenses_x': 120, 'Traffic_Accidents_x': 120, ...}`

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:

# %%
#They are the same

# %%
StdDev('driving_licenses', combined_datasets.year)
# Out:
# {'driving_licenses': 7.349818164823644}

# %%
combined_datasets.std()
# Out:
# year                               7.349818
# No. of Accidents               46493.705035
# No. of Casualties - Dead         549.783381
# No. of Casualties - Injured     2922.641127
# driving_licenses               47419.058819
# dtype: float64

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which regions have the highest and lowest Driving Licenses based on years (1993 - 2017)
# - Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)
# - What are the regions that have more Driving Licenses issued in each year than the year average?
# - What are the regions that have more Traffic Accidents happened in each year than the year average?
#
# Based on what you've just observed, have you identified any regions that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#first sort the data by driving_licenses and grouped by year to get the highest number used .first() and the lowest used .last()
highest_and_lowest_Licenses = combined_datasets[['year','driving_licenses','region']].sort_values(by='driving_licenses',ascending=False).groupby(['year'])

# %%
#the region with the highest driving licenses numbers issued 
highest_and_lowest_Licenses.first()
# Out:
#       driving_licenses   region
# year
# 1993          103886.0   Riyadh
# 1994          110545.0   Riyadh
# 1995          101608.0   Riyadh
# 1996          110131.0   Riyadh
# 1997           92145.0   Riyadh
# 1998          114962.0   Riyadh
# 1999          103535.0   Makkah
# 2000           87053.0   Makkah
# 2001           85593.0   Makkah
# 2002           88593.0   Makkah
# 2003           82697.0  Eastern
# 2004           86636.0   Makkah
# 2005           82505.0  Eastern
# 2006           79517.0  Eastern
# 2007          106511.0  Eastern
# 2008          104626.0  Eastern
# 2009          112045.0   Makkah
# 2010          113531.0   Makkah
# 2011          151087.0  Eastern
# 2012          143954.0   Makkah
# 2013          165994.0   Riyadh
# 2014          194208.0   Riyadh
# 2015          157389.0   Makkah
# 2016          242851.0   Riyadh
# 2017          495307.0   Riyadh

# %%
#the region with the lowest driving licenses numbers issued 
highest_and_lowest_Licenses.last()
# Out:
#       driving_licenses            region
# year
# 1993            1510.0  Northern Boarder
# 1994            1457.0  Northern Boarder
# 1995            1318.0  Northern Boarder
# 1996            1383.0  Northern Boarder
# 1997            1531.0  Northern Boarder
# 1998            2014.0  Northern Boarder
# 1999            2311.0  Northern Boarder
# 2000            2894.0  Northern Boarder
# 2001            2971.0  Northern Boarder
# 2002            2268.0  Northern Boarder
# 2003            1705.0  Northern Boarder
# 2004            1922.0  Northern Boarder
# 2005            1804.0  Northern Boarder
# 2006            2573.0  Northern Boarder
# 2007             997.0           Al-Baha
# 2008            3519.0  Northern Boarder
# 2009            3649.0  Northern Boarder
# 2010            3064.0  Northern Boarder
# 2011            4314.0  Northern Boarder
# 2012            3706.0  Northern Boarder
# 2013            3921.0  Northern Boarder
# 2014            5009.0  Northern Boarder
# ...

# %% [raw]
# Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)?

# %%
#groupby region and get the mean and sort the number of accidents 
combined_datasets.groupby(['region','year']).mean().sort_values('No. of Accidents', ascending=False).head(20)
# Out:
#                        No. of Accidents  No. of Casualties - Dead  \
# region           year
# Makkah           2017          145541.0                    1641.0
# Riyadh           2016          141736.0                    1430.0
# Makkah           2016          134838.0                    2243.0
# Eastern Region   2016          101619.0                    1113.0
# Riyadh           2017           99925.0                    1399.0
# Eastern Region   2017           81433.0                     963.0
# Asir             2016           32684.0                     983.0
# Jazan            2016           25873.0                     514.0
# Qassim           2016           25664.0                     397.0
# Asir             2017           25245.0                     828.0
# Qassim           2017           22405.0                     319.0
# Jazan            2017           22161.0                     466.0
# Madinah          2017           16070.0                     580.0
# ...

# %% [raw]
#  What are the regions that have more Driving Licenses issued in each year than the year average?

# %%
average_license_isseued_peryear = combined_datasets.groupby('year').driving_licenses.mean()
combined_datasets['average_license_per_year'] = combined_datasets.year.apply(lambda x: average_license_isseued_peryear[x])

# %%
highest_regions_licenses = combined_datasets[combined_datasets.driving_licenses > combined_datasets.average_license_per_year]
highest_regions_licenses.sort_values('driving_licenses', ascending=False).head(10)
# Out:
#      year   region            x_x             y_x  No. of Accidents  \
# 24   2017   Riyadh  23.0814341634   45.5857512766           99925.0
# 11   2016   Riyadh  23.0814341634   45.5857512766          141736.0
# 161  2014   Riyadh            NaN             NaN               NaN
# 83   2013   Riyadh            NaN             NaN               NaN
# 86   2015   Makkah            NaN             NaN               NaN
# 113  2011  Eastern            NaN             NaN               NaN
# 90   2014   Makkah            NaN             NaN               NaN
# 26   2012   Makkah            NaN             NaN               NaN
# 20   2017   Makkah   21.628962766   41.2636898334          145541.0
# 249  2016  Eastern            NaN             NaN               NaN
#
#      No. of Casualties - Dead  No. of Casualties - Injured  driving_licenses  \
# 24                     1399.0                       4540.0          495307.0
# ...

# %%
combined_datasets.groupby('region')['driving_licenses'].sum().plot(kind='bar');
plt.savefig('number_of_driving_licenses_issued.png')

# %%
####What are the regions that have more Traffic Accidents happened in each year than the year average

# %%
average_accidents_peryear = combined_datasets.groupby('year')['No. of Accidents'].mean()
combined_datasets['average_accidents_peryear'] = combined_datasets.year.apply(lambda x: year_ave[x])

# %%
highest_regions_accidents = combined_datasets[combined_datasets['No. of Accidents'] > combined_datasets.average_accidents_peryear]
highest_regions_accidents.sort_values('No. of Accidents', ascending=False).head()
# Out:
#     year          region            x_x             y_x  No. of Accidents  \
# 20  2017          Makkah   21.628962766   41.2636898334          145541.0
# 11  2016          Riyadh  23.0814341634   45.5857512766          141736.0
# 7   2016          Makkah   21.628962766   41.2636898334          134838.0
# 3   2016  Eastern Region  23.2883307307   50.1478302439          101619.0
# 24  2017          Riyadh  23.0814341634   45.5857512766           99925.0
#
#     No. of Casualties - Dead  No. of Casualties - Injured  driving_licenses  \
# 20                    1641.0                      10623.0          142487.0
# 11                    1430.0                       4207.0          242851.0
# 7                     2243.0                      12383.0          136055.0
# 3                     1113.0                       4893.0               NaN
# 24                    1399.0                       4540.0          495307.0
#
#               x_y             y_y  average_license_per_year  \
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#sns.heatmap(combined_datasets.corr())
def correlation_heat_map(df):
    corrs = combined_datasets.corr()
    # Set the default matplotlib figure size:
    fig, ax = plt.subplots(figsize=(11, 7))
    # Generate a mask for the upper triangle (taken from seaborn example gallery)
    mask = np.zeros_like(corrs, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    # Plot the heatmap with seaborn.
    # Assign the matplotlib axis the function returns. This will let us resize the labels.
    ax = sns.heatmap(corrs, mask=mask, annot=True)
    # Resize the labels.
    ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14, rotation=30)
    ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14, rotation=0)
    # If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
    plt.show()

# %%
correlation_heat_map(combined_datasets)

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(10,10)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_xlabel(list_of_xlabels[i])
        plt.xticks(rotation=50)
        ax[i].set_ylabel(list_of_ylabels[i])
        ax[i].set_title(list_of_titles[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Driving Licenses number
# - Traffic Accidents number
#
# Please plot two additional histograms that will help with your understanding of the data

# %%
subplot_histograms(combined_datasets, ['No. of Accidents','driving_licenses'], ['accidents histogram', 'licenses histogram'],
                   ['number of accidents', 'driving licenses issued'], ['frequency', 'frequency'])
plt.savefig('Accidents_License.png')
# Out:
# /Users/mbuhliagah/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/mbuhliagah/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - Driving Licenses vs. Traffic Accidents for 2017
# - Driving Licenses vs. Traffic Accidents for 2016
# - Driving Licenses for 2016 vs 2017
# - Traffic Accidents for 2016 vs 2017
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(14, 14))
sns.scatterplot(combined_datasets.loc[combined_datasets.year == 2017,'driving_licenses'], combined_datasets.loc[combined_datasets.year == 2017, 'No. of Accidents'], ax=ax[0,0])
sns.scatterplot(combined_datasets.loc[combined_datasets.year == 2016,'driving_licenses'], combined_datasets.loc[combined_datasets.year == 2016, 'No. of Accidents'], ax=ax[0,1])
sns.scatterplot(combined_datasets.loc[combined_datasets.year == 2016,'driving_licenses'].values, combined_datasets.loc[combined_datasets.year == 2017, 'driving_licenses'].values, ax=ax[1,0])
sns.scatterplot(combined_datasets.loc[combined_datasets.year == 2016,'No. of Accidents'].values, combined_datasets.loc[combined_datasets.year == 2017, 'No. of Accidents'].values, ax=ax[1,1])
ax[0,0].set_title('driving licenses vs number of accidents for 2017', fontsize=14)
ax[0,1].set_title('driving licenses vs number of accidents for 2016', fontsize=14)
ax[1,0].set_title('driving licenses 2016 vs 2017', fontsize=14)
ax[1,1].set_title('number of accidents 2016 vs 2017', fontsize=14)
plt.show()

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
from sklearn.preprocessing import MinMaxScaler
scl = MinMaxScaler()

combined_inner_scl = pd.DataFrame(scl.fit_transform(combined_inner), columns=combined_inner.columns)

# %%
# deleting unwanted columns
combined_inner.drop(['year', 'region', 'x_x', 'y_x','x_y', 'y_y'], axis=1, inplace=True)

# %%
fig = plt.subplots(figsize= (15,10))
sns.boxplot(data = combined_inner_scl);
plt.title('outlair of numerical value', fontsize=18);
plt.savefig('casualty_outlier.png')

# %%
combined_datasets.groupby('region')['No. of Accidents','No. of Casualties - Dead', 'No. of Casualties - Injured', 'driving_licenses'].mean().plot(kind='bar', figsize=(18,7));
plt.savefig('casualty_per_region.png')

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %%
combined_datasets.describe()
# Out:
#               year  No. of Accidents  No. of Casualties - Dead  \
# count   333.000000         26.000000                 26.000000
# mean   2005.276276      38225.692308                635.384615
# std       7.349818      46493.705035                549.783381
# min    1993.000000       1414.000000                112.000000
# 25%    1999.000000      10276.250000                241.250000
# 50%    2005.000000      16050.500000                415.500000
# 75%    2012.000000      30981.250000                929.250000
# max    2017.000000     145541.000000               2243.000000
#
#        No. of Casualties - Injured  driving_licenses  \
# count                    26.000000        325.000000
# mean                   2743.038462      28915.347692
# std                    2922.641127      47419.058819
# min                     374.000000        915.000000
# 25%                     923.000000       4846.000000
# 50%                    1618.500000      10267.000000
# ...

# %% [markdown]
# |Variable |Description|
# |---|---|
# |No. of Accidents|Number of accidents shows a similar shape with a wide spread|
# |No. of Casualties - Dead| Number of deaths resulting from accidents is positively skewed as mean greater than median |
# |No. of Casualties - Injured|Number of injured resulting from accidents is positively skewed as mean greater than median |
# |driving_licenses|Number of license shows a similar shape with a wide spread |

# %%
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(12, 12))
sns.distplot(combined_datasets['No. of Casualties - Dead'], bins=10, kde=True, ax=ax[0,0])
sns.distplot(combined_datasets['No. of Casualties - Injured'], bins=10, kde=True, ax=ax[0,1])
sns.distplot(combined_datasets['No. of Accidents'], bins=10, kde=True, ax=ax[1,0])
sns.distplot(combined_datasets['driving_licenses'], bins=10, kde=True, ax=ax[1,1])
fig.suptitle('Histograms of relevant numeric variables', fontsize=24)
ax[0,0].set_xlabel('number of deaths from accidents', fontsize=10)
ax[0,1].set_xlabel('number of injured from accidents',fontsize=10)
ax[1,0].set_xlabel('number of accidents', fontsize=10)
ax[1,1].set_xlabel('number of driving licenses issued', fontsize=10)
plt.show()

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Driving Licenses
#     - Traffic Accidents
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %%
#explained above in the describtion

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code
Hypothesis_=(combined_datasets['No. of Accidents'].mean())>(combined_datasets.driving_licenses.mean())
Hypothesis_
# Out:
# True

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** regions that demonstrate interesting trends in the number of driving licenses and traffic accidents. Spend some time doing outside research on provincial and central policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Answer:

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# - Based on your exploration of the data, what are you key takeaways and recommendations?
# - Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Answer:

# %%
#the investigation shows that Makkah region is one of the heighest in number of accidents which shows that this region is eathier not save to drive or the infastructor of the region is not good. I believe with more dataset include the infastructor of the region and the level of educations of the region population could show more resanoble reason for the high number.
#Riyadh city was above average in issuing driving licienses 
# I would like to do this investgation with extra feature include gender of driving and level of education and use it with another Arab Gulf States
